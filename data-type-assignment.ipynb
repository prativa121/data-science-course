# %%
#1. creating a list of all words in the text
text="Nepal is a landlocked country with highly diverse and rich geography, culture, and religions. It is situated in South Asia on the lap of the hug Himalayas surrounded by India in the east, south, and west and China in the north.We are renowned around the globe with not only our natural heritage but also with cultural heritages too. The major heritages that are listed in the World Heritage List such as Lumbini, Chitwan National Park, Sagarmatha National Park and many more introduce us as prosperous people of small heaven. Moreover, one can see a number of temples and Kathmandu as the city of temples.The magnificent mountains in the north, undulating slopes, passes, swift-flowing crystal-like rivers, lakes, valleys, tars, etc are attractive things that identify Nepal as a piece of heaven,. It has been a major choice of a large number of foreign tourists for the last few decades. The world highest mountain Mt. Everest, called the roof of the world identifies Nepal throughout the world. It also posses a lake at the highest altitude, the deepest gorge, and so on."

# %%
#removing unwanted character
a=text.replace('.','')
a=a.replace(',','')
a
# Out:
# 'Nepal is a landlocked country with highly diverse and rich geography culture and religions It is situated in South Asia on the lap of the hug Himalayas surrounded by India in the east south and west and China in the northWe are renowned around the globe with not only our natural heritage but also with cultural heritages too The major heritages that are listed in the World Heritage List such as Lumbini Chitwan National Park Sagarmatha National Park and many more introduce us as prosperous people of small heaven Moreover one can see a number of temples and Kathmandu as the city of templesThe magnificent mountains in the north undulating slopes passes swift-flowing crystal-like rivers lakes valleys tars etc are attractive things that identify Nepal as a piece of heaven It has been a major choice of a large number of foreign tourists for the last few decades The world highest mountain Mt Everest called the roof of the world identifies Nepal throughout the world It also posses a lake at 
# ...

# %%
#converting text into list
a=a.split()

# %%
a
# Out:
# ['Nepal',
#  'is',
#  'a',
#  'landlocked',
#  'country',
#  'with',
#  'highly',
#  'diverse',
#  'and',
#  'rich',
#  'geography',
#  'culture',
#  'and',
#  'religions',
#  'It',
#  'is',
#  'situated',
#  'in',
#  'South',
#  'Asia',
#  'on',
#  'the',
#  'lap',
#  'of',
#  'the',
#  'hug',
#  'Himalayas',
#  'surrounded',
#  'by',
#  'India',
#  'in',
#  'the',
#  'east',
#  'south',
#  'and',
#  'west',
#  'and',
#  'China',
#  'in',
#  'the',
#  'northWe',
#  'are',
#  'renowned',
#  'around',
#  'the',
#  'globe',
#  'with',
#  'not',
#  'only',
#  'our',
#  'natural',
#  'heritage',
#  'but',
#  'also',
#  'with',
#  'cultural',
#  'heritages',
#  'too',
#  'The',
#  'major',
#  'heritages',
#  'that',
#  'are',
#  'listed',
#  'in',
#  'the',
#  'World',
#  'Heritage',
#  'List',
#  'such',
#  'as',
#  'Lumbini',
#  'Chitwan',
#  'National',
#  'Park',
#  'Sagarmatha',
#  'National',
#  'Park',
#  'and',
#  'many',
#  'more',
#  'introduce',
#  'us',
#  'as',
# ...

# %% [markdown]
# 2.creting dictionary that maps each unique word to the number of times it appears in text

# %%
mydic={}

# %%
a.count("Nepal")
# Out:
# 3

# %%
for i in range(len(a)):
    mydic[a[i]]=a.count(a[i])
    
    
print(mydic)
# Out:
# {'Nepal': 3, 'is': 2, 'a': 6, 'landlocked': 1, 'country': 1, 'with': 3, 'highly': 1, 'diverse': 1, 'and': 7, 'rich': 1, 'geography': 1, 'culture': 1, 'religions': 1, 'It': 3, 'situated': 1, 'in': 5, 'South': 1, 'Asia': 1, 'on': 2, 'the': 14, 'lap': 1, 'of': 8, 'hug': 1, 'Himalayas': 1, 'surrounded': 1, 'by': 1, 'India': 1, 'east': 1, 'south': 1, 'west': 1, 'China': 1, 'northWe': 1, 'are': 3, 'renowned': 1, 'around': 1, 'globe': 1, 'not': 1, 'only': 1, 'our': 1, 'natural': 1, 'heritage': 1, 'but': 1, 'also': 2, 'cultural': 1, 'heritages': 2, 'too': 1, 'The': 2, 'major': 2, 'that': 2, 'listed': 1, 'World': 1, 'Heritage': 1, 'List': 1, 'such': 1, 'as': 4, 'Lumbini': 1, 'Chitwan': 1, 'National': 2, 'Park': 2, 'Sagarmatha': 1, 'many': 1, 'more': 1, 'introduce': 1, 'us': 1, 'prosperous': 1, 'people': 1, 'small': 1, 'heaven': 2, 'Moreover': 1, 'one': 1, 'can': 1, 'see': 1, 'number': 2, 'temples': 1, 'Kathmandu': 1, 'city': 1, 'templesThe': 1, 'magnificent': 1, 'mountains': 1, 'north': 1, 'u
# ...

# %%
#3.create a set of all unique words in text

# %%
text
# Out:
# 'Nepal is a landlocked country with highly diverse and rich geography, culture, and religions. It is situated in South Asia on the lap of the hug Himalayas surrounded by India in the east, south, and west and China in the north.We are renowned around the globe with not only our natural heritage but also with cultural heritages too. The major heritages that are listed in the World Heritage List such as Lumbini, Chitwan National Park, Sagarmatha National Park and many more introduce us as prosperous people of small heaven. Moreover, one can see a number of temples and Kathmandu as the city of temples.The magnificent mountains in the north, undulating slopes, passes, swift-flowing crystal-like rivers, lakes, valleys, tars, etc are attractive things that identify Nepal as a piece of heaven,. It has been a major choice of a large number of foreign tourists for the last few decades. The world highest mountain Mt. Everest, called the roof of the world identifies Nepal throughout the world. 
# ...

# %%
#removing unwanted character
a=text.replace('.','')
a=a.replace(',','')
a
# Out:
# 'Nepal is a landlocked country with highly diverse and rich geography culture and religions It is situated in South Asia on the lap of the hug Himalayas surrounded by India in the east south and west and China in the northWe are renowned around the globe with not only our natural heritage but also with cultural heritages too The major heritages that are listed in the World Heritage List such as Lumbini Chitwan National Park Sagarmatha National Park and many more introduce us as prosperous people of small heaven Moreover one can see a number of temples and Kathmandu as the city of templesThe magnificent mountains in the north undulating slopes passes swift-flowing crystal-like rivers lakes valleys tars etc are attractive things that identify Nepal as a piece of heaven It has been a major choice of a large number of foreign tourists for the last few decades The world highest mountain Mt Everest called the roof of the world identifies Nepal throughout the world It also posses a lake at 
# ...

# %%
#converting text into list
a=text.split()
a
# Out:
# ['Nepal',
#  'is',
#  'a',
#  'landlocked',
#  'country',
#  'with',
#  'highly',
#  'diverse',
#  'and',
#  'rich',
#  'geography,',
#  'culture,',
#  'and',
#  'religions.',
#  'It',
#  'is',
#  'situated',
#  'in',
#  'South',
#  'Asia',
#  'on',
#  'the',
#  'lap',
#  'of',
#  'the',
#  'hug',
#  'Himalayas',
#  'surrounded',
#  'by',
#  'India',
#  'in',
#  'the',
#  'east,',
#  'south,',
#  'and',
#  'west',
#  'and',
#  'China',
#  'in',
#  'the',
#  'north.We',
#  'are',
#  'renowned',
#  'around',
#  'the',
#  'globe',
#  'with',
#  'not',
#  'only',
#  'our',
#  'natural',
#  'heritage',
#  'but',
#  'also',
#  'with',
#  'cultural',
#  'heritages',
#  'too.',
#  'The',
#  'major',
#  'heritages',
#  'that',
#  'are',
#  'listed',
#  'in',
#  'the',
#  'World',
#  'Heritage',
#  'List',
#  'such',
#  'as',
#  'Lumbini,',
#  'Chitwan',
#  'National',
#  'Park,',
#  'Sagarmatha',
#  'National',
#  'Park',
#  'and',
#  'many',
#  'more',
#  'introduce',
#  'us',
#  'as',
# ...

# %%
#converting list into set
a=set(a)

# %%
a
# Out:
# {'Asia',
#  'China',
#  'Chitwan',
#  'Everest,',
#  'Heritage',
#  'Himalayas',
#  'India',
#  'It',
#  'Kathmandu',
#  'List',
#  'Lumbini,',
#  'Moreover,',
#  'Mt.',
#  'National',
#  'Nepal',
#  'Park',
#  'Park,',
#  'Sagarmatha',
#  'South',
#  'The',
#  'World',
#  'a',
#  'also',
#  'altitude,',
#  'and',
#  'are',
#  'around',
#  'as',
#  'at',
#  'attractive',
#  'been',
#  'but',
#  'by',
#  'called',
#  'can',
#  'choice',
#  'city',
#  'country',
#  'crystal-like',
#  'cultural',
#  'culture,',
#  'decades.',
#  'deepest',
#  'diverse',
#  'east,',
#  'etc',
#  'few',
#  'for',
#  'foreign',
#  'geography,',
#  'globe',
#  'gorge,',
#  'has',
#  'heaven,.',
#  'heaven.',
#  'heritage',
#  'heritages',
#  'highest',
#  'highly',
#  'hug',
#  'identifies',
#  'identify',
#  'in',
#  'introduce',
#  'is',
#  'lake',
#  'lakes,',
#  'landlocked',
#  'lap',
#  'large',
#  'last',
#  'listed',
#  'magnificent',
#  'major',
#  'many',
#  'more',
#  'mountain',
#  'mountains',
# ...

# %%
#printing five most common words in the text and their frequency

# %%
text
# Out:
# 'Nepal is a landlocked country with highly diverse and rich geography, culture, and religions. It is situated in South Asia on the lap of the hug Himalayas surrounded by India in the east, south, and west and China in the north.We are renowned around the globe with not only our natural heritage but also with cultural heritages too. The major heritages that are listed in the World Heritage List such as Lumbini, Chitwan National Park, Sagarmatha National Park and many more introduce us as prosperous people of small heaven. Moreover, one can see a number of temples and Kathmandu as the city of temples.The magnificent mountains in the north, undulating slopes, passes, swift-flowing crystal-like rivers, lakes, valleys, tars, etc are attractive things that identify Nepal as a piece of heaven,. It has been a major choice of a large number of foreign tourists for the last few decades. The world highest mountain Mt. Everest, called the roof of the world identifies Nepal throughout the world. 
# ...

# %%
#removing unwanted character
a=text.replace('.','')
a=a.replace(',','')
a
# Out:
# 'Nepal is a landlocked country with highly diverse and rich geography culture and religions It is situated in South Asia on the lap of the hug Himalayas surrounded by India in the east south and west and China in the northWe are renowned around the globe with not only our natural heritage but also with cultural heritages too The major heritages that are listed in the World Heritage List such as Lumbini Chitwan National Park Sagarmatha National Park and many more introduce us as prosperous people of small heaven Moreover one can see a number of temples and Kathmandu as the city of templesThe magnificent mountains in the north undulating slopes passes swift-flowing crystal-like rivers lakes valleys tars etc are attractive things that identify Nepal as a piece of heaven It has been a major choice of a large number of foreign tourists for the last few decades The world highest mountain Mt Everest called the roof of the world identifies Nepal throughout the world It also posses a lake at 
# ...

# %%
a=a.split()
a
# Out:
# ['Nepal',
#  'is',
#  'a',
#  'landlocked',
#  'country',
#  'with',
#  'highly',
#  'diverse',
#  'and',
#  'rich',
#  'geography',
#  'culture',
#  'and',
#  'religions',
#  'It',
#  'is',
#  'situated',
#  'in',
#  'South',
#  'Asia',
#  'on',
#  'the',
#  'lap',
#  'of',
#  'the',
#  'hug',
#  'Himalayas',
#  'surrounded',
#  'by',
#  'India',
#  'in',
#  'the',
#  'east',
#  'south',
#  'and',
#  'west',
#  'and',
#  'China',
#  'in',
#  'the',
#  'northWe',
#  'are',
#  'renowned',
#  'around',
#  'the',
#  'globe',
#  'with',
#  'not',
#  'only',
#  'our',
#  'natural',
#  'heritage',
#  'but',
#  'also',
#  'with',
#  'cultural',
#  'heritages',
#  'too',
#  'The',
#  'major',
#  'heritages',
#  'that',
#  'are',
#  'listed',
#  'in',
#  'the',
#  'World',
#  'Heritage',
#  'List',
#  'such',
#  'as',
#  'Lumbini',
#  'Chitwan',
#  'National',
#  'Park',
#  'Sagarmatha',
#  'National',
#  'Park',
#  'and',
#  'many',
#  'more',
#  'introduce',
#  'us',
#  'as',
# ...

# %%
for i in range(len(a)):
    print (a[i] ,"frequency is", a.count(a[i]))
# Out:
# Nepal frequency is 3
# is frequency is 2
# a frequency is 6
# landlocked frequency is 1
# country frequency is 1
# with frequency is 3
# highly frequency is 1
# diverse frequency is 1
# and frequency is 7
# rich frequency is 1
# geography frequency is 1
# culture frequency is 1
# and frequency is 7
# religions frequency is 1
# It frequency is 3
# is frequency is 2
# situated frequency is 1
# in frequency is 5
# South frequency is 1
# Asia frequency is 1
# on frequency is 2
# the frequency is 14
# lap frequency is 1
# of frequency is 8
# the frequency is 14
# hug frequency is 1
# Himalayas frequency is 1
# surrounded frequency is 1
# by frequency is 1
# India frequency is 1
# in frequency is 5
# the frequency is 14
# east frequency is 1
# south frequency is 1
# and frequency is 7
# west frequency is 1
# and frequency is 7
# China frequency is 1
# in frequency is 5
# the frequency is 14
# northWe frequency is 1
# are frequency is 3
# renowned frequency is 1
# around frequency is 1
# ...

# %%
for i in range(len(a)):
    mydic[a[i]]=a.count(a[i])
    
    
print(mydic)
# Out:
# {'Nepal': 3, 'is': 2, 'a': 6, 'landlocked': 1, 'country': 1, 'with': 3, 'highly': 1, 'diverse': 1, 'and': 7, 'rich': 1, 'geography': 1, 'culture': 1, 'religions': 1, 'It': 3, 'situated': 1, 'in': 5, 'South': 1, 'Asia': 1, 'on': 2, 'the': 14, 'lap': 1, 'of': 8, 'hug': 1, 'Himalayas': 1, 'surrounded': 1, 'by': 1, 'India': 1, 'east': 1, 'south': 1, 'west': 1, 'China': 1, 'northWe': 1, 'are': 3, 'renowned': 1, 'around': 1, 'globe': 1, 'not': 1, 'only': 1, 'our': 1, 'natural': 1, 'heritage': 1, 'but': 1, 'also': 2, 'cultural': 1, 'heritages': 2, 'too': 1, 'The': 2, 'major': 2, 'that': 2, 'listed': 1, 'World': 1, 'Heritage': 1, 'List': 1, 'such': 1, 'as': 4, 'Lumbini': 1, 'Chitwan': 1, 'National': 2, 'Park': 2, 'Sagarmatha': 1, 'many': 1, 'more': 1, 'introduce': 1, 'us': 1, 'prosperous': 1, 'people': 1, 'small': 1, 'heaven': 2, 'Moreover': 1, 'one': 1, 'can': 1, 'see': 1, 'number': 2, 'temples': 1, 'Kathmandu': 1, 'city': 1, 'templesThe': 1, 'magnificent': 1, 'mountains': 1, 'north': 1, 'u
# ...

# %%
from collections import OrderedDict
import numpy as np
keys = list(mydic.keys())
values = list(mydic.values())
sorted_value_index = np.argsort(values)
sorted_dict = {keys[i]: values[i] for i in sorted_value_index}
 
print(sorted_dict)
# Out:
# {'Sagarmatha': 1, 'lakes': 1, 'rivers': 1, 'crystal-like': 1, 'swift-flowing': 1, 'passes': 1, 'slopes': 1, 'undulating': 1, 'north': 1, 'mountains': 1, 'magnificent': 1, 'templesThe': 1, 'valleys': 1, 'city': 1, 'temples': 1, 'see': 1, 'can': 1, 'one': 1, 'Moreover': 1, 'small': 1, 'people': 1, 'prosperous': 1, 'us': 1, 'introduce': 1, 'more': 1, 'Kathmandu': 1, 'tars': 1, 'etc': 1, 'attractive': 1, 'deepest': 1, 'altitude': 1, 'at': 1, 'lake': 1, 'posses': 1, 'throughout': 1, 'identifies': 1, 'roof': 1, 'called': 1, 'Everest': 1, 'Mt': 1, 'mountain': 1, 'decades': 1, 'few': 1, 'last': 1, 'for': 1, 'tourists': 1, 'foreign': 1, 'large': 1, 'choice': 1, 'been': 1, 'has': 1, 'piece': 1, 'identify': 1, 'things': 1, 'many': 1, 'gorge': 1, 'so': 1, 'south': 1, 'only': 1, 'not': 1, 'globe': 1, 'around': 1, 'renowned': 1, 'northWe': 1, 'China': 1, 'west': 1, 'Chitwan': 1, 'east': 1, 'India': 1, 'by': 1, 'surrounded': 1, 'Himalayas': 1, 'hug': 1, 'situated': 1, 'lap': 1, 'our': 1, 'South': 1
# ...

# %%
#most five common word in text
for x in list(sorted_dict)[-5:]:
    print (x)
# Out:
# in
# a
# and
# of
# the
